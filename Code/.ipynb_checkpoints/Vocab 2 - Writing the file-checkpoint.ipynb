# %%
import re
import numpy as np
import pandas as pd

from collections import OrderedDict
from operator import itemgetter

# %%
def get_vocab(ifile):
    dataset = pd.read_csv(ifile, header=None) #ISSUE: Detects first row as headings

    dt_array = np.array(dataset, dtype="<U2000") 
    #ISSUE 1: Without dtype all cells are saved a 'str' except for the empty ones (which are saved as 'float')
    # --> Using dtype = 'str' is not a solution (it crops the string after 64 'unicode' characters)
    # --> We can use as dtype a unicode with a large number ('str' = '<U64'), something like '<U1400'
    # --> Or don't use a dtype but then cast each cell as str().
    #ISSUE 2: We have html code here (e.g. 'web site:\\nAir Fleet<br />\\n  <br />\\n670 aircraft, including: <br />\\n47 Airbus A300-600s  17 Boeing DC10-30s')
    text_array = dt_array[:,1:]

    vocab = {}
    for row in text_array:  
        text_in_row = ' '.join(row)
        text_in_row = ''.join(re.findall("[a-zA-Z0-9 '-]*", text_in_row)).lower()
        words_in_row = text_in_row.split()
        #print(words_in_row, '\n')
        for word in words_in_row:
            try:
                vocab[word] = vocab[word] + 1
            except:
                vocab[word] = 1

    ord_vocab = OrderedDict(sorted(vocab.items(), key = itemgetter(1), reverse = True))
    
    return ord_vocab

# %%
input_file = "../Datasets/yahoo_answers_csv/train.csv"
ord_vocab = get_vocab(input_file)
ord_vocab
# Out:
# OrderedDict([('the', 5123832),
#              ('to', 3440346),
#              ('a', 2937199),
#              ('and', 2921464),
#              ('i', 2367582),
#              ('of', 2282312),
#              ('is', 2149337),
#              ('you', 2132617),
#              ('in', 1765213),
#              ('it', 1547272),
#              ('that', 1410317),
#              ('for', 1195491),
#              ('are', 970199),
#              ('have', 949997),
#              ('on', 858982),
#              ('be', 830434),
#              ('or', 778141),
#              ('with', 769224),
#              ('do', 768690),
#              ('what', 754856),
#              ('your', 747669),
#              ('if', 736966),
#              ('can', 712251),
#              ('not', 697786),
#              ('my', 684938),
#              ('this', 658125),
#              ('nan', 656764),
#              ('but', 645973),
#              ('they', 624346),
#              ('as', 559005),
#              ('will', 502843),
#              ('he', 489699),
#              ('was', 487162),
#              ('how', 475816),
#              ('me', 471595),
#              ('like', 431882),
#              ('get', 425265),
#              ('so', 424011),
#              ('from', 420239),
#              ('at', 411221),
#              ('there', 405648),
#              ('all', 404878),
#              ('would', 395832),
#              ('just', 380439),
#              ('about', 379757),
#              ('know', 368599),
#              ('one', 365323),
#              ('an', 364854),
#              ('when', 345547),
#              ('out', 343901),
#              ('by', 338365),
#              ('we', 319661),
#              ('has', 309225),
#              ('who', 305120),
#              ('think', 294297),
#              ('some', 284060),
#              ('people', 281925),
#              ('up', 279938),
#              ('them', 272571),
#              ('more', 271451),
#              ('no', 269892),
#              ('any', 265512),
#              ("don't", 262835),
#              ('want', 256197),
#              ('then', 254035),
#              ('good', 248812),
#              ('go', 241187),
#              ('her', 237753),
#              ('him', 234666),
#              ('why', 230621),
#              ('should', 230300),
#              ('their', 229066),
#              ('time', 226434),
#              ('other', 225807),
#              ('need', 225196),
#              ('she', 223816),
#              ('does', 220102),
#              ('his', 213173),
#              ('am', 212912),
#              ('-', 211670),
#              ('because', 210714),
#              ('which', 209522),
#              ('help', 205334),
#              ('make', 199568),
#              ('only', 193222),
#              ('also', 186059),
#              ('really', 185938),
#              ("it's", 184617),
#              ('where', 174818),
#              ('find', 173304),
#              ('had', 169960),
#              ('than', 168236),
#              ('way', 166223),
#              ('been', 165776),
#              ('see', 159422),
#              ("i'm", 157611),
#              ('its', 157178),
#              ('could', 156232),
#              ('now', 151173),
#              ('many', 150029),
#              ('were', 149136),
#              ('very', 148323),
#              ('best', 146379),
#              ('much', 145474),
#              ('most', 144279),
#              ('use', 139658),
#              ('u', 139147),
#              ('into', 137949),
#              ('take', 137102),
#              ('first', 136726),
#              ('work', 136440),
#              ('say', 134014),
#              ('love', 133922),
#              ('even', 132261),
#              ('us', 130518),
#              ('may', 126927),
#              ('did', 125689),
#              ('back', 122334),
#              ('anyone', 120531),
#              ('right', 118889),
#              ('tell', 118280),
#              ('going', 118201),
#              ('over', 117779),
#              ('something', 117591),
#              ('after', 117506),
#              ('well', 116899),
#              ('our', 115605),
#              ('these', 113576),
#              ('years', 113291),
#              ('try', 112842),
#              ('question', 112450),
#              ('2', 112182),
#              ('too', 110472),
#              ('same', 109457),
#              ('someone', 109380),
#              ('give', 108906),
#              ('still', 106999),
#              ('new', 106563),
#              ('being', 106253),
#              ('life', 102779),
#              ('please', 102444),
#              ('things', 101167),
#              ('day', 100487),
#              ('two', 100017),
#              ('world', 99648),
#              ('dont', 97251),
#              ('better', 95456),
#              ('answer', 95321),
#              ('never', 94713),
#              ('before', 92853),
#              ('feel', 92679),
#              ('sure', 90818),
#              ('here', 90712),
#              ('person', 90451),
#              ('look', 89711),
#              ('god', 89687),
#              ('off', 88873),
#              ('thing', 87593),
#              ('got', 86292),
#              ('used', 85596),
#              ('down', 85006),
#              ('name', 83895),
#              ('always', 83839),
#              ('long', 83265),
#              ('year', 82621),
#              ('those', 82424),
#              ("can't", 82357),
#              ('mean', 81548),
#              ('school', 79527),
#              ('1', 79474),
#              ('said', 77009),
#              ('come', 76470),
#              ('old', 75759),
#              ('money', 75642),
#              ('around', 75479),
#              ('through', 74865),
#              ('such', 74724),
#              ('free', 74368),
#              ('anything', 74252),
#              ('each', 74068),
#              ('ask', 74059),
#              ('different', 73962),
#              ('both', 73346),
#              ('every', 73335),
#              ('put', 73277),
#              ('another', 72446),
#              ('believe', 72136),
#              ('might', 71092),
#              ('ever', 71028),
#              ('lot', 70713),
#              ('great', 70609),
#              ('yes', 70038),
#              ('own', 69896),
#              ('little', 69001),
#              ('start', 68646),
#              ('im', 68241),
#              ('guy', 68005),
#              ('without', 67707),
#              ('3', 67574),
#              ('keep', 67380),
#              ('man', 66791),
#              ('since', 66308),
#              ('while', 66204),
#              ('called', 66002),
#              ('looking', 65661),
#              ('bad', 64488),
#              ('made', 64384),
#              ('computer', 63852),
#              ('friend', 63587),
#              ('last', 63392),
#              ('home', 63005),
#              ('let', 62808),
#              ('doing', 62733),
#              ('problem', 62388),
#              ("doesn't", 62343),
#              ('between', 61705),
#              ('live', 61685),
#              ('water', 61678),
#              ("you're", 60456),
#              ('hard', 59007),
#              ('getting', 58930),
#              ('n', 58417),
#              ('friends', 57984),
#              ('number', 57378),
#              ('body', 56904),
#              ('few', 56778),
#              ('using', 55674),
#              ('job', 55627),
#              ('having', 55622),
#              ('site', 55063),
#              ('luck', 54996),
#              ('girl', 54774),
#              ("i've", 54160),
#              ('etc', 53929),
#              ('state', 53725),
#              ('place', 53325),
#              ('probably', 53254),
#              ('real', 53090),
#              ('yahoo', 53001),
#              ('else', 52623),
#              ('high', 52611),
#              ('able', 52426),
#              ('check', 52225),
#              ('times', 52087),
#              ('country', 51829),
#              ('away', 51641),
#              ('again', 51618),
#              ('pay', 51492),
#              ('big', 51172),
#              ('maybe', 50633),
#              ('sex', 50594),
#              ('information', 50577),
#              ('4', 50571),
#              ('actually', 50499),
#              ('though', 50378),
#              ('talk', 50260),
#              ('change', 50248),
#              ('show', 50228),
#              ('found', 49789),
#              ('trying', 49475),
#              ('system', 49474),
#              ('women', 49233),
#              ('done', 48824),
#              ('call', 48711),
#              ('must', 48679),
#              ('part', 48658),
#              ("that's", 48345),
#              ('says', 47768),
#              ('nothing', 47629),
#              ('next', 47245),
#              ('means', 47069),
#              ('read', 46872),
#              ('enough', 46672),
#              ('end', 46128),
#              ('yourself', 46104),
#              ('wrong', 45727),
#              ('usually', 45469),
#              ('5', 44993),
#              ('days', 44836),
#              ('play', 44709),
#              ('10', 44580),
#              ('once', 44393),
#              ('guys', 44300),
#              ('family', 44168),
#              ('told', 43981),
#              ('true', 43815),
#              ('type', 43693),
#              ('website', 43556),
#              ('point', 43442),
#              ('cause', 43312),
#              ('business', 43305),
#              ('kind', 43103),
#              ('however', 42916),
#              ('makes', 42607),
#              ('either', 42515),
#              ('internet', 42466),
#              ('under', 42143),
#              ('stop', 41816),
#              ('word', 41783),
#              ('hope', 41589),
#              ('everything', 41401),
#              ('men', 41325),
#              ('buy', 41230),
#              ("didn't", 40988),
#              ('possible', 40895),
#              ('weight', 40725),
#              ('song', 40529),
#              ('others', 40411),
#              ('small', 40236),
#              ('less', 39874),
#              ('team', 39739),
#              ('care', 39673),
#              ('against', 39567),
#              ('house', 39559),
#              ('during', 39366),
#              ('american', 39328),
#              ('until', 39221),
#              ('run', 38627),
#              ('answers', 38416),
#              ('already', 38350),
#              ('become', 37777),
#              ('sometimes', 37687),
#              ('questions', 37676),
#              ("he's", 37512),
#              ('least', 37435),
#              ('game', 37351),
#              ('left', 37331),
#              ('reason', 37307),
#              ('open', 37121),
#              ('side', 36965),
#              ('everyone', 36840),
#              ('together', 36712),
#              ('war', 36684),
#              ('area', 36346),
#              ('x', 36241),
#              ('went', 36215),
#              ('far', 36113),
#              ('heard', 35697),
#              ('click', 35401),
#              ('program', 35247),
#              ('ok', 35194),
#              ('company', 35177),
#              ('set', 35176),
#              ('search', 35023),
#              ('children', 35013),
#              ('understand', 34813),
#              ('thought', 34809),
#              ('example', 34718),
#              ('pretty', 34448),
#              ('law', 34430),
#              ('music', 34359),
#              ('three', 34188),
#              ("isn't", 34187),
#              ('remember', 34027),
#              ('matter', 34011),
#              ('course', 33952),
#              ('girls', 33860),
#              ('college', 33845),
#              ('child', 33692),
#              ('case', 33629),
#              ('eat', 33616),
#              ('form', 33561),
#              ('light', 33433),
#              ('states', 33320),
#              ('making', 33314),
#              ('government', 33223),
#              ('often', 33178),
#              ('book', 33120),
#              ('age', 33032),
#              ('idea', 33026),
#              ('learn', 33018),
#              ('power', 32889),
#              ('cant', 32858),
#              ('comes', 32762),
#              ('kids', 32693),
#              ('ago', 32515),
#              ('win', 32515),
#              ('second', 32505),
#              ('web', 32443),
#              ('blood', 32385),
#              ('working', 32337),
#              ("won't", 32158),
#              ('important', 32136),
#              ('months', 32061),
#              ('woman', 31982),
#              ('movie', 31952),
#              ('stuff', 31944),
#              ('earth', 31800),
#              ('talking', 31754),
#              ('wants', 31734),
#              ('move', 31731),
#              ('seen', 31691),
#              ('mind', 31653),
#              ('white', 31611),
#              ('doctor', 31557),
#              ('thanks', 31516),
#              ('week', 31201),
#              ('english', 31107),
#              ('relationship', 31080),
#              ('night', 31055),
#              ('problems', 31048),
#              ('ur', 31013),
#              ('6', 30974),
#              ('line', 30897),
#              ('top', 30829),
#              ('gets', 30782),
#              ('goes', 30764),
#              ('whole', 30695),
#              ('started', 30655),
#              ('black', 30631),
#              ('windows', 30610),
#              ('heart', 30558),
#              ('fact', 30525),
#              ('jesus', 30415),
#              ('online', 30314),
#              ('file', 30212),
#              ('yet', 30152),
#              ('helps', 30119),
#              ('came', 29966),
#              ('cannot', 29876),
#              ('needs', 29862),
#              ('email', 29834),
#              ('support', 29783),
#              ('taking', 29726),
#              ('seems', 29692),
#              ('nice', 29673),
#              ('control', 29583),
#              ('asked', 29359),
#              ('order', 29358),
#              ('link', 29256),
#              ('today', 29166),
#              ('depends', 28991),
#              ('card', 28908),
#              ('given', 28822),
#              ('stay', 28516),
#              ("you'll", 28376),
#              ('download', 28301),
#              ('married', 28251),
#              ('food', 28244),
#              ('leave', 28193),
#              ('credit', 28148),
#              ('works', 28070),
#              ('tried', 27968),
#              ('list', 27949),
#              ('energy', 27944),
#              ('bush', 27817),
#              ("what's", 27745),
#              ('words', 27691),
#              ('human', 27607),
#              ('write', 27404),
#              ('contact', 27352),
#              ('happen', 27257),
#              ('normal', 27146),
#              ('full', 27054),
#              ('send', 27028),
#              ('parents', 27016),
#              ('ones', 27003),
#              ('saying', 26883),
#              ('history', 26838),
#              ('pain', 26645),
#              ('lost', 26592),
#              ('lose', 26592),
#              ('cup', 26436),
#              ('watch', 26410),
#              ('bit', 26326),
#              ('known', 26271),
#              ('easy', 26197),
#              ('head', 26131),
#              ('test', 26099),
#              ('almost', 26080),
#              ('local', 25952),
#              ('happy', 25828),
#              ('drive', 25823),
#              ('america', 25741),
#              ('page', 25681),
#              ('wanted', 25644),
#              ('turn', 25616),
#              ('points', 25500),
#              ('air', 25451),
#              ('class', 25407),
#              ('phone', 25388),
#              ('past', 25362),
#              ('seem', 25312),
#              ('experience', 25160),
#              ('group', 25110),
#              ('car', 25060),
#              ('due', 25026),
#              ('president', 24972),
#              ('player', 24938),
#              ('common', 24932),
#              ('difference', 24919),
#              ('husband', 24915),
#              ('myself', 24852),
#              ('close', 24837),
#              ('address', 24679),
#              ('certain', 24674),
#              ('per', 24645),
#              ('amount', 24605),
#              ('date', 24572),
#              ('instead', 24543),
#              ('software', 24529),
#              ('info', 24492),
#              ('thinking', 24478),
#              ('hand', 24405),
#              ("i'd", 24382),
#              ('12', 24377),
#              ('fun', 24371),
#              ('hate', 24188),
#              ('living', 24185),
#              ('several', 24089),
#              ('religion', 24045),
#              ('add', 24043),
#              ('knows', 23926),
#              ('bible', 23849),
#              ("there's", 23749),
#              ('20', 23738),
#              ('thats', 23583),
#              ('based', 23555),
#              ('hours', 23537),
#              ('asking', 23528),
#              ('rather', 23467),
#              ('boyfriend', 23427),
#              ('sound', 23375),
#              ('later', 23352),
#              ('hear', 23160),
#              ('choose', 23091),
#              ('c', 23064),
#              ('son', 23062),
#              ('took', 23041),
#              ('guess', 22998),
#              ('month', 22989),
#              ('level', 22823),
#              ('above', 22811),
#              ('below', 22782),
#              ('takes', 22693),
#              ('hurt', 22691),
#              ('alot', 22484),
#              ('especially', 22436),
#              ('--', 22403),
#              ('young', 22318),
#              ('united', 22311),
#              ('account', 22241),
#              ('explain', 22205),
#              ('red', 22127),
#              ('face', 22118),
#              ('low', 21997),
#              ('sounds', 21988),
#              ('service', 21954),
#              ('rest', 21877),
#              ('office', 21817),
#              ('b', 21808),
#              ('cost', 21759),
#              ('r', 21757),
#              ('public', 21740),
#              ('language', 21707),
#              ("wouldn't", 21677),
#              ('ideas', 21662),
#              ('speed', 21648),
#              ('size', 21634),
#              ('health', 21573),
#              ('fat', 21560),
#              ('simple', 21552),
#              ('unless', 21493),
#              ('wife', 21413),
#              ('100', 21411),
#              ('likely', 21400),
#              ('deal', 21328),
#              ('large', 21316),
#              ('within', 21313),
#              ('death', 21303),
#              ('period', 21259),
#              ('advice', 21256),
#              ('hot', 21252),
#              ('usa', 21196),
#              ('whats', 21135),
#              ('term', 21132),
#              ('couple', 21105),
#              ('following', 21101),
#              ('personal', 21046),
#              ('whether', 21033),
#              ('sites', 21018),
#              ('process', 20971),
#              ('tv', 20908),
#              ('short', 20903),
#              ('looks', 20865),
#              ("they're", 20792),
#              ('running', 20732),
#              ('chance', 20698),
#              ('legal', 20691),
#              ('sorry', 20619),
#              ('force', 20585),
#              ('along', 20580),
#              ('video', 20580),
#              ('space', 20562),
#              ('coming', 20561),
#              ('city', 20530),
#              ('lots', 20520),
#              ('7', 20501),
#              ('hair', 20419),
#              ('8', 20400),
#              ('general', 20349),
#              ('likes', 20348),
#              ('countries', 20347),
#              ('15', 20329),
#              ('court', 20313),
#              ('happened', 20233),
#              ('whatever', 20179),
#              ('single', 20177),
#              ('agree', 20044),
#              ('quite', 20042),
#              ('mother', 19987),
#              ('illegal', 19984),
#              ('skin', 19982),
#              ('current', 19974),
#              ('major', 19961),
#              ('ball', 19928),
#              ('act', 19914),
#              ('worth', 19846),
#              ('baby', 19832),
#              ('favorite', 19807),
#              ('study', 19663),
#              ('available', 19657),
#              ('half', 19653),
#              ('ways', 19640),
#              ('break', 19578),
#              ('happens', 19571),
#              ('hit', 19473),
#              ('rate', 19399),
#              ('sleep', 19343),
#              ('football', 19327),
#              ('weeks', 19312),
#              ('games', 19244),
#              ('serious', 19235),
#              ('simply', 19202),
#              ('de', 19187),
#              ('wait', 19187),
#              ('india', 19140),
#              ('taken', 19105),
#              ('pick', 18859),
#              ('longer', 18826),
#              ('saw', 18806),
#              ('specific', 18791),
#              ('church', 18755),
#              ('eyes', 18730),
#              ('soon', 18729),
#              ('special', 18672),
#              ('programs', 18649),
#              ('30', 18594),
#              ('files', 18581),
#              ('research', 18571),
#              ('although', 18497),
#              ('sign', 18473),
#              ('fast', 18466),
#              ('father', 18458),
#              ('create', 18457),
#              ('suggest', 18429),
#              ('born', 18427),
#              ('iraq', 18426),
#              ('gay', 18394),
#              ('situation', 18391),
#              ('wish', 18387),
#              ('interested', 18314),
#              ('medical', 18301),
#              ('themselves', 18254),
#              ('correct', 18248),
#              ('stupid', 18177),
#              ('feeling', 18152),
#              ('pc', 18118),
#              ('sense', 18087),
#              ('tax', 18057),
#              ('future', 17980),
#              ('party', 17977),
#              ('field', 17941),
#              ('degree', 17930),
#              ('opinion', 17874),
#              ('pressure', 17863),
#              ('ie', 17859),
#              ('exactly', 17857),
#              ('boy', 17843),
#              ('americans', 17837),
#              ('meaning', 17819),
#              ('anybody', 17771),
#              ('hell', 17754),
#              ('wondering', 17751),
#              ('mom', 17746),
#              ('value', 17708),
#              ('education', 17670),
#              ('hold', 17609),
#              ('science', 17586),
#              ("i'll", 17537),
#              ('average', 17512),
#              ('similar', 17512),
#              ('consider', 17502),
#              ('christian', 17435),
#              ('plan', 17419),
#              ('bring', 17418),
#              ('gave', 17404),
#              ('inside', 17399),
#              ('thank', 17391),
#              ('mass', 17380),
#              ('including', 17362),
#              ('playing', 17312),
#              ('higher', 17175),
#              ('trust', 17171),
#              ("aren't", 17156),
#              ('die', 17126),
#              ('middle', 17126),
#              ('fine', 17102),
#              ('lives', 16982),
#              ('oil', 16972),
#              ('room', 16963),
#              ('paper', 16952),
#              ('save', 16905),
#              ('lol', 16882),
#              ('stand', 16857),
#              ('paid', 16754),
#              ('meet', 16754),
#              ('allow', 16750),
#              ('cell', 16738),
#              ('data', 16718),
#              ('early', 16715),
#              ('wear', 16698),
#              ('story', 16658),
#              ('doesnt', 16614),
#              ('cut', 16581),
#              ('numbers', 16567),
#              ('players', 16522),
#              ('university', 16522),
#              ('fight', 16502),
#              ('cool', 16479),
#              ('military', 16446),
#              ('clear', 16445),
#              ('front', 16374),
#              ('fall', 16373),
#              ('books', 16364),
#              ('marriage', 16346),
#              ('mail', 16342),
#              ('gives', 16331),
#              ('sell', 16331),
#              ('sun', 16306),
#              ('minutes', 16241),
#              ('outside', 16219),
#              ('alone', 16184),
#              ("haven't", 16160),
#              ('provide', 16109),
#              ('plus', 16100),
#              ('drink', 15976),
#              ('figure', 15942),
#              ('laws', 15903),
#              ('y', 15902),
#              ('natural', 15894),
#              ('diet', 15884),
#              ('interest', 15858),
#              ('considered', 15851),
#              ('needed', 15845),
#              ('speak', 15824),
#              ('truth', 15812),
#              ("she's", 15805),
#              ('social', 15788),
#              ('follow', 15776),
#              ('spend', 15773),
#              ('oh', 15771),
#              ('behind', 15716),
#              ('cd', 15668),
#              ('national', 15646),
#              ('companies', 15636),
#              ('google', 15616),
#              ('wanna', 15603),
#              ('vote', 15512),
#              ('feet', 15507),
#              ('mine', 15485),
#              ('offer', 15477),
#              ('strong', 15457),
#              ('giving', 15449),
#              ('cold', 15402),
#              ('code', 15402),
#              ('report', 15388),
#              ('store', 15380),
#              ('created', 15375),
#              ('rights', 15332),
#              ('security', 15317),
#              ('lower', 15250),
#              ('south', 15220),
#              ('starting', 15135),
#              ('issue', 15130),
#              ('shows', 15092),
#              ('physical', 15073),
#              ('price', 15024),
#              ('d', 15019),
#              ('walk', 15009),
#              ('recently', 14945),
#              ('effect', 14911),
#              ('kill', 14853),
#              ('main', 14845),
#              ('won', 14829),
#              ('four', 14782),
#              ('rid', 14749),
#              ('total', 14744),
#              ('color', 14744),
#              ('box', 14742),
#              ('brain', 14710),
#              ('jobs', 14699),
#              ('self', 14697),
#              ('access', 14695),
#              ("you've", 14658),
#              ('gas', 14648),
#              ('played', 14618),
#              ('record', 14603),
#              ('increase', 14598),
#              ('female', 14573),
#              ('anyway', 14567),
#              ('police', 14538),
#              ('view', 14537),
#              ('source', 14529),
#              ('season', 14521),
#              ('enjoy', 14515),
#              ('gone', 14510),
#              ('songs', 14508),
#              ('completely', 14480),
#              ('picture', 14476),
#              ('cells', 14467),
#              ('listen', 14462),
#              ('worry', 14406),
#              ('safe', 14404),
#              ('exercise', 14374),
#              ('share', 14348),
#              ('students', 14324),
#              ('eating', 14305),
#              ('wont', 14293),
#              ('eye', 14286),
#              ('la', 14272),
#              ('blue', 14250),
#              ('market', 14239),
#              ('green', 14231),
#              ('places', 14219),
#              ('yeah', 14194),
#              ('nni', 14155),
#              ('funny', 14141),
#              ('version', 14139),
#              ('near', 14133),
#              ('include', 14131),
#              ('project', 14123),
#              ('heat', 14088),
#              ('difficult', 14073),
#              ('pass', 14070),
#              ('christians', 14063),
#              ('respect', 14052),
#              ('apply', 14032),
#              ('50', 14031),
#              ('sort', 14018),
#              ('gonna', 14007),
#              ('land', 14003),
#              ('older', 13995),
#              ('student', 13948),
#              ('choice', 13936),
#              ('worked', 13935),
#              ('nnthe', 13925),
#              ('result', 13923),
#              ('john', 13915),
#              ('schools', 13895),
#              ('england', 13891),
#              ('post', 13877),
#              ('ready', 13825),
#              ('million', 13809),
#              ('generally', 13808),
#              ('hi', 13793),
#              ('names', 13789),
#              ('vs', 13781),
#              ('feelings', 13756),
#              ('9', 13748),
#              ('itself', 13735),
#              ('18', 13728),
#              ("wasn't", 13710),
#              ('written', 13673),
#              ('remove', 13668),
#              ('involved', 13639),
#              ('results', 13617),
#              ('hands', 13589),
#              ('w', 13588),
#              ('step', 13586),
#              ('hey', 13570),
#              ('dead', 13567),
#              ('reading', 13531),
#              ('details', 13526),
#              ('complete', 13525),
#              ('loves', 13523),
#              ('causes', 13497),
#              ('2006', 13473),
#              ('knew', 13444),
#              ('poor', 13440),
#              ('media', 13437),
#              ('anymore', 13421),
#              ('letter', 13421),
#              ('daughter', 13410),
#              ('teacher', 13338),
#              ('bank', 13335),
#              ('m', 13315),
#              ('position', 13304),
#              ('xp', 13303),
#              ('reasons', 13299),
#              ('male', 13295),
#              ('clean', 13275),
#              ('thinks', 13258),
#              ('died', 13245),
#              ('upon', 13226),
#              ('movies', 13220),
#              ('according', 13212),
#              ('14', 13189),
#              ('therefore', 13189),
#              ('ex', 13179),
#              ('disease', 13155),
#              ('theory', 13143),
#              ('healthy', 13135),
#              ('forget', 13127),
#              ('types', 13121),
#              ('hour', 13080),
#              ('straight', 13079),
#              ('copy', 13073),
#              ('north', 13064),
#              ('present', 13060),
#              ('sent', 13059),
#              ('huge', 13054),
#              ('0', 13024),
#              ('terms', 13000),
#              ('insurance', 12997),
#              ('society', 12984),
#              ('related', 12973),
#              ('late', 12951),
#              ('allowed', 12947),
#              ('cancer', 12945),
#              ('met', 12944),
#              ('message', 12918),
#              ('telling', 12889),
#              ('issues', 12887),
#              ('16', 12854),
#              ('except', 12849),
#              ('lead', 12842),
#              ('perfect', 12837),
#              ('moving', 12836),
#              ('original', 12835),
#              ('network', 12828),
#              ('product', 12806),
#              ('practice', 12796),
#              ('virus', 12785),
#              ('grow', 12755),
#              ('charge', 12748),
#              ('websites', 12741),
#              ('drug', 12722),
#              ('return', 12683),
#              ('basically', 12664),
#              ('basic', 12623),
#              ('training', 12605),
#              ('property', 12575),
#              ('match', 12519),
#              ('center', 12513),
#              ('changed', 12485),
#              ('solution', 12477),
#              ('effects', 12475),
#              ('continue', 12467),
#              ('writing', 12457),
#              ('didnt', 12452),
#              ('news', 12403),
#              ('birth', 12342),
#              ('build', 12316),
#              ('uk', 12292),
#              ('rock', 12284),
#              ('changes', 12278),
#              ('girlfriend', 12251),
#              ('13', 12238),
#              ('key', 12230),
#              ('currently', 12218),
#              ('recommend', 12217),
#              ('worse', 12216),
#              ('sick', 12192),
#              ('brother', 12155),
#              ('loss', 12129),
#              ('supposed', 12115),
#              ('dad', 12091),
#              ('okay', 12075),
#              ('totally', 12071),
#              ('25', 12070),
#              ('income', 12068),
#              ('series', 12067),
#              ('rules', 12064),
#              ('distance', 12043),
#              ('attention', 12015),
#              ('drugs', 12004),
#              ('caused', 11930),
#              ('easier', 11927),
#              ('trouble', 11915),
#              ('accept', 11911),
#              ('religious', 11911),
#              ('depending', 11910),
#              ('options', 11906),
#              ('teams', 11891),
#              ('perhaps', 11876),
#              ('parts', 11866),
#              ('bill', 11832),
#              ('race', 11808),
#              ('morning', 11804),
#              ...])

# %%
vocab_file = "Yahoo_answers_VOCAB.txt"
num_words = 10000
with open(vocab_file, 'w') as textfile:
    for i, word in enumerate(ord_vocab):
        if i < num_words:
            textfile.write(word + "\t" + str(i+1) + "\t" + str(ord_vocab[word]) + "\n")

# %% [markdown]
# ## Useful for determining what stays (by using a smaller dataset)

# %%
ord_vocab['the']
# Out:
# 5123832

# %%
for i, word in enumerate(ord_vocab):
    if i<10:
        print(word)
    else:
        break
# Out:
# the
# to
# a
# and
# i
# of
# is
# you
# in
# it
